# %%
import pandas as pd
import json

# %%
with open("twitter_data_Demonitization.txt","r") as f:
    data = json.load(f)

# %%
data
# Out:
# {'Text': ['5 saal ka Rasan Paani Pichle ghotale Ke Karan\n#MahaThagBandhan Ke pass Jo tha,khatam hone par Aa gaya\nActual fàyda… https://t.co/sBpTgXrcK1',
#   'RT @dravirmani: #BION (Believe it or not; Humour dont take too seriously):  #Bhakts &amp; #Darbaris agree on 1 issue. #Demonitization structura…',
#   'RT @dravirmani: #BION (Believe it or not; Humour dont take too seriously):  #Bhakts &amp; #Darbaris agree on 1 issue. #Demonitization structura…',
#   'RT @dravirmani: #BION (Believe it or not; Humour dont take too seriously):  #Bhakts &amp; #Darbaris agree on 1 issue. #Demonitization structura…',
#   '#BION (Believe it or not; Humour dont take too seriously):  #Bhakts &amp; #Darbaris agree on 1 issue. #Demonitization s… https://t.co/Ubdm7kpOqD',
#   'എന്തായിരുന്നു നിങ്ങളുടെ നോട്ട് നിരോധന ഓർമ്മകൾ?\nഇപ്പോൾ തിരിഞ്ഞു നോക്കുമ്പോൾ എന്തു തോന്നുന്നു?\n#demonitization',
# ...

# %%
 tweets = pd.DataFrame.from_dict(data)
# Out:
#                                                  Text          User_id
# 0   5 saal ka Rasan Paani Pichle ghotale Ke Karan\...  kumar_rajeev555
# 1   RT @dravirmani: #BION (Believe it or not; Humo...      docbhooshan
# 2   RT @dravirmani: #BION (Believe it or not; Humo...     RashmiRathi_
# 3   RT @dravirmani: #BION (Believe it or not; Humo...           vcs_17
# 4   #BION (Believe it or not; Humour dont take too...       dravirmani
# 5   എന്തായിരുന്നു നിങ്ങളുടെ നോട്ട് നിരോധന ഓർമ്മകൾ?...  Letterstonowhe1
# 6   കള്ളപ്പണക്കാർ ഇനി അനുഭവിക്കാൻ പോവുകയാണെന്നും ഉ...  Letterstonowhe1
# 7   @BJP4India #SkillIndia #Demonitization #SwachB...   beautywithekta
# 8   @gautamexplorer @ndtv Who is chaukidar Mr?? #R...      SandStone03
# 9   @abhijitmajumder You #BJP supporters have only...      SandStone03
# 10  RT @gopalparekh: no mention of #demonitization...  Vinubha48672724
# 11  no mention of #demonitization in #BharatKeMann...      gopalparekh
# ...

# %%
data.head(5)
# Out:
# Empty DataFrame
# ...
